# %%
import pandas as pd

df = pd.read_csv("../data/cleaned_data.csv")

X = df.drop("Class", axis=1)
y = df["Class"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,stratify=y, random_state=42)

# %%
print(y_train.value_counts(normalize=True))
print(y_test.value_counts(normalize=True))
# Out:
# Class
# 0    0.998271
# 1    0.001729
# Name: proportion, dtype: float64
# Class
# 0    0.99828
# 1    0.00172
# Name: proportion, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_scaled, y_train)
print(y_train.value_counts())
print(y_train_resampled.value_counts())
# Out:
# Class
# 0    227451
# 1       394
# Name: count, dtype: int64
# Class
# 0    227451
# 1    227451
# Name: count, dtype: int64

# %%
features_names = X.columns

import joblib

joblib.dump(X_train_resampled, "../data/X_train.pkl")
joblib.dump(y_train_resampled, "../data/y_train.pkl")
joblib.dump(X_test_scaled, "../data/X_test.pkl")
joblib.dump(y_test, "../data/y_test.pkl")
joblib.dump(scaler, "../models/scaler.pkl")
joblib.dump(features_names, "../data/features_names.pkl")
# Out:
# ['../data/features_names.pkl']
